# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


reviews = pd.read_csv("./cleaned-reviews.csv")
reviews.shape
reviews
# Out:
#       Unnamed: 0                                            reviews  rates  \
# 0              0  ✅ Trip Verified | Excellent service both on th...      5
# 1              1  ✅ Trip Verified |  Good lounge at Cape Town. O...      9
# 2              2  ✅ Trip Verified |  A really excellent journey....      9
# 3              3  ✅ Trip Verified |  This flight was one of the ...      9
# 4              4  Not Verified | It seems that there is a race t...      2
# ...          ...                                                ...    ...
# 3406        3413  Flew British Airways from Sydney to Venice on ...     10
# 3407        3414  Recently for our honeymoon we took advantage o...      1
# 3408        3415  LGW-Antigua on 29 April and Antigua-LGW on 13 ...      4
# 3409        3416  LHR-JTR-LHR. A tale of opposites for BA's new ...      2
# 3410        3417  Gatwick-Venice return. Two contrasting experie...      2
#
#             date         country  verified  \
# ...

# %%
reviews.drop_duplicates(inplace=True)
reviews.shape
reviews
# Out:
#       Unnamed: 0                                            reviews  rates  \
# 0              0  ✅ Trip Verified | Excellent service both on th...      5
# 1              1  ✅ Trip Verified |  Good lounge at Cape Town. O...      9
# 2              2  ✅ Trip Verified |  A really excellent journey....      9
# 3              3  ✅ Trip Verified |  This flight was one of the ...      9
# 4              4  Not Verified | It seems that there is a race t...      2
# ...          ...                                                ...    ...
# 3406        3413  Flew British Airways from Sydney to Venice on ...     10
# 3407        3414  Recently for our honeymoon we took advantage o...      1
# 3408        3415  LGW-Antigua on 29 April and Antigua-LGW on 13 ...      4
# 3409        3416  LHR-JTR-LHR. A tale of opposites for BA's new ...      2
# 3410        3417  Gatwick-Venice return. Two contrasting experie...      2
#
#             date         country  verified  \
# ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3411 entries, 0 to 3410
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3411 non-null   int64
#  1   reviews     3411 non-null   object
#  2   rates       3411 non-null   int64
#  3   date        3411 non-null   object
#  4   country     3411 non-null   object
#  5   verified    3411 non-null   bool
#  6   comments    3411 non-null   object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 189.9+ KB

# %%
pd.to_datetime(reviews.date)
reviews
# Out:
#       Unnamed: 0                                            reviews  rates  \
# 0              0  ✅ Trip Verified | Excellent service both on th...      5
# 1              1  ✅ Trip Verified |  Good lounge at Cape Town. O...      9
# 2              2  ✅ Trip Verified |  A really excellent journey....      9
# 3              3  ✅ Trip Verified |  This flight was one of the ...      9
# 4              4  Not Verified | It seems that there is a race t...      2
# ...          ...                                                ...    ...
# 3406        3413  Flew British Airways from Sydney to Venice on ...     10
# 3407        3414  Recently for our honeymoon we took advantage o...      1
# 3408        3415  LGW-Antigua on 29 April and Antigua-LGW on 13 ...      4
# 3409        3416  LHR-JTR-LHR. A tale of opposites for BA's new ...      2
# 3410        3417  Gatwick-Venice return. Two contrasting experie...      2
#
#             date         country  verified  \
# ...

# %%
reviews.isnull().value_counts()
# Out:
# Unnamed: 0  reviews  rates  date   country  verified  comments
# False       False    False  False  False    False     False       3411
# dtype: int64

# %%
reviews.rates.describe()
# Out:
# count    3411.000000
# mean        4.821167
# std         3.145863
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         8.000000
# max        10.000000
# Name: rates, dtype: float64

# %% [markdown]
# ## Analisis inicial:
#
# #### No encontramos datos faltantes, outliers o inconsistentes
