# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
airline = pd.read_csv('./customer_airways_data.csv', encoding='latin1')

# %%
reviews = pd.read_csv('./cleaned-reviews.csv', encoding='latin1')

# %%
# Limpiamos archivos
airline.drop_duplicates(inplace=True)
airline = airline.loc[airline.booking_origin != "(not set)",:]

reviews['date'] = pd.to_datetime(reviews['date'], errors='coerce')

# %% [markdown]
# #### Creo una funcion para mapear los meses a estaciones del año.
# ##### no uso dt.season porque no reconoce la funciòn

# %%
def get_season(date):
  month = date.month
  seasons = {
      1: "Verano",
      2: "Verano",
      3: "Otoño",
      4: "Otoño",
      5: "Otoño",
      6: "Invierno",
      7: "Invierno",
      8: "Invierno",
      9: "Primavera",
      10: "Primavera",
      11: "Primavera",
      12: "Verano"
  }
  return seasons.get(month)

# %% [markdown]
# #### Agregamos una columna para representar la estacion del año

# %%
reviews['season'] = reviews['date'].map(get_season)
reviews
# Out:
#       Unnamed: 0                                            reviews  rates  \
# 0              0  â
#  Trip Verified | Excellent service both on ...      5
# 1              1  â
#  Trip Verified |  Good lounge at Cape Town....      9
# 2              2  â
#  Trip Verified |  A really excellent journe...      9
# 3              3  â
#  Trip Verified |  This flight was one of th...      9
# 4              4  Not Verified | It seems that there is a race t...      2
# ...          ...                                                ...    ...
# 3406        3413  Flew British Airways from Sydney to Venice on ...     10
# 3407        3414  Recently for our honeymoon we took advantage o...      1
# 3408        3415  LGW-Antigua on 29 April and Antigua-LGW on 13 ...      4
# 3409        3416  LHR-JTR-LHR. A tale of opposites for BA's new ...      2
# 3410        3417  Gatwick-Venice return. Two contrasting experie...      2
#
#            date         country  verified  \
# 0    2023-01-24  United Kingdom      True
# 1    2023-01-24  United Kingdom      True
# 2    2023-01-23  United Kingdom      True
# 3    2023-01-21  United Kingdom      True
# 4    2023-01-19   United States     False
# ...         ...             ...       ...
# 3406 2014-05-20       Australia     False
# 3407 2014-05-19  United Kingdom     False
# 3408 2014-05-18  United Kingdom     False
# 3409 2014-05-18  United Kingdom     False
# 3410 2014-05-18  United Kingdom     False
#
#                                                comments  season
# 0     excellent service ground board first class pro...  Verano
# 1     good lounge cape town time departure drink hig...  Verano
# 2     really excellent journey lounge overcrowded la...  Verano
# 3     flight one worst ever life wanted pamper bough...  Verano
# 4     verified seems race bottom amongst airline can...  Verano
# ...                                                 ...     ...
# 3406  flew british airway sydney venice nd april ret...   Otoño
# 3407  recently honeymoon took advantage ba promo fly...   Otoño
# 3408  lgw antigua april antigua lgw may boeing start...   Otoño
# 3409  lhr jtr lhr tale opposite ba new route santori...   Otoño
# 3410  gatwick venice return two contrasting experien...   Otoño
#
# [3411 rows x 8 columns]

# %% [markdown]
# #### Agrupamos por estacion del año

# %%
reviews = reviews.groupby(['season','country']).size()
reviews = reviews.unstack(level=0)
reviews
# Out:
# season                Invierno  Otoño  Primavera  Verano
# country
# Argentina                  NaN    2.0        3.0     1.0
# Australia                 45.0   28.0       51.0    23.0
# Austria                    NaN    2.0        5.0     3.0
# Bahrain                    NaN    1.0        NaN     NaN
# Barbados                   1.0    NaN        NaN     NaN
# ...                        ...    ...        ...     ...
# Ukraine                    1.0    NaN        NaN     NaN
# United Arab Emirates       5.0    4.0        8.0     3.0
# United Kingdom           547.0  520.0      598.0   500.0
# United States             97.0   59.0       96.0   109.0
# Vietnam                    NaN    NaN        NaN     1.0
#
# [69 rows x 4 columns]

# %% [markdown]
# #### Dado que tenemos algunas columnas sin datos, las eliminamos porque no tenemos informacion relevante

# %%
reviews = reviews[~reviews.isnull().any(axis=1)]

# %%
reviews
# Out:
# season                Invierno  Otoño  Primavera  Verano
# country
# Australia                 45.0   28.0       51.0    23.0
# Belgium                    3.0   11.0        4.0     3.0
# Brazil                     1.0    1.0        1.0     1.0
# Canada                    31.0   19.0       27.0    27.0
# Denmark                    3.0    2.0        3.0     3.0
# France                     1.0    7.0        9.0     9.0
# Germany                   15.0   14.0       17.0    14.0
# Hong Kong                  8.0    3.0        2.0     1.0
# India                      2.0    6.0        3.0     6.0
# Ireland                    9.0    8.0       12.0     7.0
# Italy                      6.0    3.0        6.0     3.0
# Kuwait                     1.0    2.0        1.0     1.0
# Malaysia                   1.0    2.0        9.0     2.0
# Mexico                     1.0    2.0        2.0     3.0
# Netherlands               12.0    5.0        9.0     6.0
# New Zealand                3.0    2.0        5.0     1.0
# Singapore                  9.0    4.0       11.0     3.0
# South Africa              12.0    7.0        7.0    11.0
# Spain                      6.0    7.0        7.0     6.0
# Sweden                     2.0    4.0        6.0     7.0
# Switzerland               12.0   11.0        9.0     5.0
# Thailand                   8.0    2.0        8.0     5.0
# United Arab Emirates       5.0    4.0        8.0     3.0
# United Kingdom           547.0  520.0      598.0   500.0
# United States             97.0   59.0       96.0   109.0

# %% [markdown]
# #### Ahora filtramos los paises de airline

# %%
airline = airline.merge(reviews, left_on='booking_origin', right_on='country', how='inner')
airline
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   1      Internet  RoundTrip             96              31
# 3                   1      Internet  RoundTrip              3              48
# 4                   3      Internet  RoundTrip            201              33
# ...               ...           ...        ...            ...             ...
# 31429               2      Internet  RoundTrip            173               6
# 31430               1      Internet  RoundTrip            101               6
# 31431               1      Internet     OneWay             53              40
# 31432               1      Internet  RoundTrip             24               4
# 31433               1      Internet  RoundTrip             50               5
#
#        flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0                7        Sat  AKLDEL    New Zealand                    1
# 1                3        Sat  AKLDEL    New Zealand                    0
# 2                4        Sat  AKLDEL    New Zealand                    0
# 3               20        Thu  AKLDEL    New Zealand                    1
# 4                6        Thu  AKLDEL    New Zealand                    1
# ...            ...        ...     ...            ...                  ...
# 31429           18        Sat  LGKTPE         Canada                    0
# 31430           15        Fri  MAATPE         Canada                    1
# 31431           20        Thu  MELXIY   South Africa                    0
# 31432           12        Mon  HDYTPE   South Africa                    1
# 31433            8        Thu  HKTPUS   South Africa                    0
#
#        wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                         0                      0             5.52
# 1                         0                      0             5.52
# 2                         0                      1             5.52
# 3                         0                      1             5.52
# 4                         0                      1             5.52
# ...                     ...                    ...              ...
# 31429                     0                      0             4.67
# 31430                     0                      0             4.67
# 31431                     0                      1             8.83
# 31432                     0                      0             4.67
# 31433                     0                      0             6.33
#
#        booking_complete  Invierno  Otoño  Primavera  Verano
# 0                     0       3.0    2.0        5.0     1.0
# 1                     0       3.0    2.0        5.0     1.0
# 2                     0       3.0    2.0        5.0     1.0
# 3                     0       3.0    2.0        5.0     1.0
# 4                     0       3.0    2.0        5.0     1.0
# ...                 ...       ...    ...        ...     ...
# 31429                 0      31.0   19.0       27.0    27.0
# 31430                 0      31.0   19.0       27.0    27.0
# 31431                 0      12.0    7.0        7.0    11.0
# 31432                 0      12.0    7.0        7.0    11.0
# 31433                 0      12.0    7.0        7.0    11.0
#
# [31434 rows x 18 columns]

# %% [markdown]
# #### Calculamos el porcentaje correspondiente a las reservas por pais

# %%
airline_percentage = airline.groupby('booking_origin')['booking_complete'].mean()*100
airline_percentage
# Out:
# booking_origin
# Australia                5.059070
# Belgium                 14.285714
# Brazil                   0.000000
# Canada                   3.508772
# Denmark                 42.857143
# France                  22.413793
# Germany                 20.370370
# Hong Kong               24.489796
# India                   10.174881
# Ireland                  0.000000
# Italy                   18.965517
# Kuwait                  22.222222
# Malaysia                34.500354
# Mexico                  11.111111
# Netherlands              4.444444
# New Zealand              5.000000
# Singapore               28.529981
# South Africa             0.000000
# Spain                    3.703704
# Sweden                  41.666667
# Switzerland             16.666667
# Thailand                23.281485
# United Arab Emirates     7.142857
# United Kingdom          12.138728
# United States           18.322296
# Name: booking_complete, dtype: float64

# %%
for pais, porcentaje in airline_percentage.items():
    reviews.loc[pais] = reviews.loc[pais] * porcentaje / 100
  
reviews
# Out:
# season                 Invierno      Otoño  Primavera     Verano
# country
# Australia              2.276581   1.416539   2.580125   1.163586
# Belgium                0.428571   1.571429   0.571429   0.428571
# Brazil                 0.000000   0.000000   0.000000   0.000000
# Canada                 1.087719   0.666667   0.947368   0.947368
# Denmark                1.285714   0.857143   1.285714   1.285714
# France                 0.224138   1.568966   2.017241   2.017241
# Germany                3.055556   2.851852   3.462963   2.851852
# Hong Kong              1.959184   0.734694   0.489796   0.244898
# India                  0.203498   0.610493   0.305246   0.610493
# Ireland                0.000000   0.000000   0.000000   0.000000
# Italy                  1.137931   0.568966   1.137931   0.568966
# Kuwait                 0.222222   0.444444   0.222222   0.222222
# Malaysia               0.345004   0.690007   3.105032   0.690007
# Mexico                 0.111111   0.222222   0.222222   0.333333
# Netherlands            0.533333   0.222222   0.400000   0.266667
# New Zealand            0.150000   0.100000   0.250000   0.050000
# Singapore              2.567698   1.141199   3.138298   0.855899
# South Africa           0.000000   0.000000   0.000000   0.000000
# Spain                  0.222222   0.259259   0.259259   0.222222
# Sweden                 0.833333   1.666667   2.500000   2.916667
# Switzerland            2.000000   1.833333   1.500000   0.833333
# Thailand               1.862519   0.465630   1.862519   1.164074
# United Arab Emirates   0.357143   0.285714   0.571429   0.214286
# United Kingdom        66.398844  63.121387  72.589595  60.693642
# United States         17.772627  10.810155  17.589404  19.971302

# %% [markdown]
# #### Uniformizamos porque hay valores muy distantes (el grafico no se va a ver bien)

# %%
reviews = np.log1p(reviews)
reviews
# Out:
# season                Invierno     Otoño  Primavera    Verano
# country
# Australia             0.782440  0.632514   0.822155  0.571977
# Belgium               0.305037  0.664985   0.372932  0.305037
# Brazil                0.000000  0.000000   0.000000  0.000000
# Canada                0.551625  0.412656   0.510713  0.510713
# Denmark               0.602499  0.481833   0.602499  0.602499
# France                0.184184  0.664492   0.744003  0.744003
# Germany               0.875505  0.853800   0.914614  0.853800
# Hong Kong             0.734727  0.438791   0.335500  0.198075
# India                 0.169939  0.389702   0.236172  0.389702
# Ireland               0.000000  0.000000   0.000000  0.000000
# Italy                 0.565222  0.371851   0.565222  0.371851
# Kuwait                0.182880  0.313149   0.182880  0.182880
# Malaysia              0.259589  0.421819   0.880545  0.421819
# Mexico                0.100172  0.182880   0.182880  0.252844
# Netherlands           0.355885  0.182880   0.290033  0.212195
# New Zealand           0.130819  0.091038   0.201424  0.047637
# Singapore             0.820626  0.566090   0.883885  0.481419
# South Africa          0.000000  0.000000   0.000000  0.000000
# Spain                 0.182880  0.207440   0.207440  0.182880
# Sweden                0.473831  0.683516   0.812157  0.860880
# Switzerland           0.741276  0.713662   0.650391  0.473831
# Thailand              0.718670  0.323738   0.718670  0.572105
# United Arab Emirates  0.266495  0.224195   0.372932  0.177440
# United Kingdom        1.650700  1.641087   1.667424  1.633580
# United States         1.369250  1.243855   1.366753  1.397025

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(reviews, cmap="YlOrBr")


plt.xlabel("Estacion del año")
plt.ylabel("País")
plt.title("Muestreo de reservas  completas (%) por estacion del año")
# Out:
# Text(0.5, 1.0, 'Muestreo de reservas por estacion del año')
